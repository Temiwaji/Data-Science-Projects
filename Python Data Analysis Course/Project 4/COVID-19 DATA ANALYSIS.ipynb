# %% [markdown]
# ## PYTHON DATA ANALYSIS - PROJECT 4
# ### COVID-19 DATA ANALYSIS

# %% [markdown]
# ![covid-cells.jpg](attachment:covid-cells.jpg)

# %% [markdown]
# This is a small dataset of Covid-19, just for understaning purposes. The data used here is till 29-April-2020 and has records as on 29-April-2020.
#
# This data is available as a CSV file, downloaded from Kaggle.
#
# We will analyze this data using the Pandas DataFrame.

# %%
# Import necessary libraries
import pandas as pd

# %%
# Load dataset
covid_data = pd.read_csv(r"C:\Users\User\Documents\Scholarships application\Women Techstars Application\certifications\Udemy\Python Data Analytics\Project 4\Covid_19_data.csv")

# %%
covid_data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %%
# Check the number of non null-values in the dataframe
covid_data.count()
# Out:
# Date         321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %%
# Check the number of null values
covid_data.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
# Check null values in form of heatmap
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(covid_data.isnull())
plt.show()

# %% [markdown]
# The white space in the heatmap indicates that there are null values under the state column

# %% [markdown]
# ### Q.1  Show the number of Confirmed , Deaths and Recovered cases in each Region.

# %%
#df.groupby('Region').sum().head(50)
#df.groupby('Region')['Confirmed'].sum().sort_values(ascending=False).head(20)
#df.groupby('Region')['Confirmed', 'Recovered'].sum()

# %%
covid_data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
covid_data.groupby("Region").sum()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_22508\2856964770.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   covid_data.groupby("Region").sum()
#                     Confirmed  Deaths  Recovered
# Region
# Afghanistan              1939      60        252
# Albania                   766      30        455
# Algeria                  3848     444       1702
# Andorra                   743      42        423
# Angola                     27       2          7
# ...                       ...     ...        ...
# West Bank and Gaza        344       2         71
# Western Sahara              6       0          5
# Yemen                       6       0          1
# Zambia                     97       3         54
# Zimbabwe                   32       4          5
#
# [187 rows x 3 columns]

# %% [markdown]
# This Shows the result of each region in the formof their summed up values.

# %%
# Check for top regions based only confirmed cases
#df.groupby('Region')['Confirmed'].sum().sort_values(ascending=False).head(20)
covid_data.groupby("Region")["Confirmed"].sum().sort_values(ascending = False).head(20)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166543
# UK                 166441
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82862
# Brazil              79685
# Canada              52865
# Belgium             47859
# Netherlands         38998
# Peru                33931
# India               33062
# Switzerland         29407
# Ecuador             24675
# Portugal            24505
# Saudi Arabia        21402
# Name: Confirmed, dtype: int64

# %%
# Check for top regions based only confirmed and recovered cases
#df.groupby('Region')['Confirmed', 'Recovered'].sum()
covid_data.groupby("Region")["Confirmed", "Recovered"].sum()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_22508\3323744835.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   covid_data.groupby("Region")["Confirmed", "Recovered"].sum()
#                     Confirmed  Recovered
# Region
# Afghanistan              1939        252
# Albania                   766        455
# Algeria                  3848       1702
# Andorra                   743        423
# Angola                     27          7
# ...                       ...        ...
# West Bank and Gaza        344         71
# Western Sahara              6          5
# Yemen                       6          1
# Zambia                     97         54
# Zimbabwe                   32          5
#
# [187 rows x 2 columns]

# %% [markdown]
# ### Q2 Remove all the records where Confirmed Cases is Less Than 10.

# %%
#df.Confirmed < 10
#df[df.Confirmed < 10]
#df[~(df.Confirmed < 10)]
#df = df[~(df.Confirmed < 10)]

# %%
covid_data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
covid_data[~(covid_data.Confirmed < 10)]
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [304 rows x 6 columns]

# %%
# Make the records removed satisfying a particular condition permanently
covid_data = covid_data[~(covid_data.Confirmed < 10)]

# %%
covid_data.head(20)
# Out:
#          Date State                  Region  Confirmed  Deaths  Recovered
# 0   4/29/2020   NaN             Afghanistan       1939      60        252
# 1   4/29/2020   NaN                 Albania        766      30        455
# 2   4/29/2020   NaN                 Algeria       3848     444       1702
# 3   4/29/2020   NaN                 Andorra        743      42        423
# 4   4/29/2020   NaN                  Angola         27       2          7
# 5   4/29/2020   NaN     Antigua and Barbuda         24       3         11
# 6   4/29/2020   NaN               Argentina       4285     214       1192
# 7   4/29/2020   NaN                 Armenia       1932      30        900
# 8   4/29/2020   NaN                 Austria      15402     580      12779
# 9   4/29/2020   NaN              Azerbaijan       1766      23       1267
# 10  4/29/2020   NaN                 Bahamas         80      11         23
# 11  4/29/2020   NaN                 Bahrain       2921       8       1455
# ...

# %% [markdown]
# ### Q.3 In which Region, maximum number of Confirmed cases were recorded ?

# %%
#df.groupby('Region').Confirmed.sum().sort_values(ascending = False).head(20)

# %%
# Ensure to go back to load the original dataset so that the removed records do not affect the output of this question.

# %%
covid_data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
covid_data.groupby("Region").Confirmed.sum().sort_values(ascending = False).head(20)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166543
# UK                 166441
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82862
# Brazil              79685
# Canada              52865
# Belgium             47859
# Netherlands         38998
# Peru                33931
# India               33062
# Switzerland         29407
# Ecuador             24675
# Portugal            24505
# Saudi Arabia        21402
# Name: Confirmed, dtype: int64

# %% [markdown]
# ### Q.4 In which Region, minimum number of Deaths cases were recorded ?

# %%
#df.groupby('Region').Deaths.sum().sort_values(ascending = True).head(50)

# %%
covid_data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
covid_data.groupby("Region").Deaths.sum().sort_values(ascending = True).head(50)
# Out:
# Region
# Laos                                0
# Mongolia                            0
# Mozambique                          0
# Cambodia                            0
# Fiji                                0
# Namibia                             0
# Nepal                               0
# Madagascar                          0
# Macau                               0
# Papua New Guinea                    0
# Rwanda                              0
# Saint Kitts and Nevis               0
# Bhutan                              0
# Dominica                            0
# Central African Republic            0
# Saint Lucia                         0
# Holy See                            0
# Sao Tome and Principe               0
# Yemen                               0
# Western Sahara                      0
# Eritrea                             0
# Vietnam                             0
# Saint Vincent and the Grenadines    0
# Timor-Leste                         0
# ...

# %% [markdown]
# ### Q.5 How many Confirmed , Deaths & Recovered cases were reported from India till 29 April 2020 ?

# %%
#df[df.Region == 'Country_name']

# %%
covid_data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
covid_data[covid_data.Region =="India"]
# Out:
#          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437

# %%
# For Nigeria
covid_data[covid_data.Region =="Nigeria"]
# Out:
#           Date State   Region  Confirmed  Deaths  Recovered
# 120  4/29/2020   NaN  Nigeria       1728      51        307

# %%
# For US
covid_data[covid_data.Region =="US"]
# Out:
#           Date                         State Region  Confirmed  Deaths  \
# 181  4/29/2020                       Alabama     US       6912     256
# 182  4/29/2020                        Alaska     US        355       9
# 186  4/29/2020                       Arizona     US       7209     308
# 187  4/29/2020                      Arkansas     US       3193      57
# 195  4/29/2020                    California     US      48747    1946
# 199  4/29/2020                      Colorado     US      14758     766
# 200  4/29/2020                   Connecticut     US      26767    2169
# 202  4/29/2020                      Delaware     US       4655     144
# 204  4/29/2020  Diamond Princess cruise ship     US         49       0
# 205  4/29/2020          District of Columbia     US       4106     205
# 208  4/29/2020                       Florida     US      33193    1218
# 213  4/29/2020                       Georgia     US      25775    1101
# ...

# %% [markdown]
# ### Q. 6-A  Sort the entire data wrt No. of Confirmed cases in ascending order.

# %%
#df.sort_values(by= ['Confirmed'] , ascending = True)

# %%
covid_data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
covid_data.sort_values(by= ["Confirmed"] , ascending = True).head(50)
# Out:
#           Date                             State  \
# 285  4/29/2020                         Recovered
# 284  4/29/2020                         Recovered
# 203  4/29/2020      Diamond Princess cruise ship
# 305  4/29/2020                             Tibet
# 289  4/29/2020         Saint Pierre and Miquelon
# 184  4/29/2020                          Anguilla
# 192  4/29/2020  Bonaire, Sint Eustatius and Saba
# 272  4/29/2020             Northwest Territories
# 288  4/29/2020                  Saint Barthelemy
# 178  4/29/2020                               NaN
# 194  4/29/2020            British Virgin Islands
# 177  4/29/2020                               NaN
# 18   4/29/2020                               NaN
# 126  4/29/2020                               NaN
# 140  4/29/2020                               NaN
# 105  4/29/2020                               NaN
# 98   4/29/2020                               NaN
# 156  4/29/2020                               NaN
# ...

# %% [markdown]
# ### Q. 6-B  Sort the entire data wrt No. of Recovered cases in descending order.

# %%
#df.sort_values(by= ['Recovered'] , ascending = False)

# %%
covid_data.sort_values(by= ["Recovered"] , ascending = False).head(50)
# Out:
#           Date            State                Region  Confirmed  Deaths  \
# 153  4/29/2020              NaN                 Spain     236899   24275
# 285  4/29/2020        Recovered                    US          0       0
# 61   4/29/2020              NaN               Germany     161539    6467
# 76   4/29/2020              NaN                  Iran      93657    5957
# 80   4/29/2020              NaN                 Italy     203591   27682
# 229  4/29/2020            Hubei        Mainland China      68128    4512
# 57   4/29/2020              NaN                France     165093   24087
# 167  4/29/2020              NaN                Turkey     117589    3081
# 22   4/29/2020              NaN                Brazil      79685    5513
# 158  4/29/2020              NaN           Switzerland      29407    1716
# 284  4/29/2020        Recovered                Canada          0       0
# 78   4/29/2020              NaN               Ireland      20253    1190
# ...
